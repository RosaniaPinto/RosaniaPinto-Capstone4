# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Import and read CSV files

# %%
cts = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\clicks_train_sample.csv')
dc = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\documents_categories.csv')
de = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\documents_entities.csv')
dm = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\documents_meta.csv')
dt = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\documents_topics.csv')
ev = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\events.csv')
pgv = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\page_views_newsample.csv')
pc = pd.read_csv('C:\\Users\\Rose\\Desktop\\Capstone4\\promoted_content.csv')
# Out:
# E:\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Merge CSV files

# %%
# Merging events 'ev' with documents_meta 'dm' using document_id
evdm = pd.merge(ev, dm, on='document_id')
evdm
# Out:
#           display_id            uuid  document_id   timestamp platform  \
# 0                  1  cb8c55702adb93       379743          61        3
# 1            1239772  a2eb3a4e0a4c08       379743    74476960        1
# 2            1306670  c9d0cf076200f3       379743    78297892        2
# 3            2357895  6e0aabe592ba61       379743   148985378        2
# 4            2785946  1eb4bef36f8623       379743   177159039        1
# ...              ...             ...          ...         ...      ...
# 23120121    23119969  15a573f86dfeb6      2994282  1295990472        2
# 23120122    23120028  f3eae20e5f3320       897027  1295994117        1
# 23120123    23120059  bffdaa000741da      2997881  1295995517        2
# 23120124    23120067  f71c55144e077d       849598  1295996093        2
# 23120125    23120081  68f52117b72501      2977263  1295997003        2
#
#          geo_location  source_id  publisher_id         publish_time
# ...

# %%
# Merging events 'ev' & documents_meta 'dm' dataframe with click_trains_sample 'cts'
evdmcts = pd.merge(evdm, cts, on='display_id')
evdmcts
# Out:
#         display_id            uuid  document_id   timestamp platform  \
# 0            34922  6288e67b1d54c6      1794259     2600122        2
# 1            36471  54d8dfb74dcef5      1794259     2729315        2
# 2            69037  eb345ac48eaa11      1794259     5686447        2
# 3            78208  d53551d0b23d67      1794259     6606779        2
# 4            94115  cfd33e4e9e05b5      1794259     8259821        1
# ...            ...             ...          ...         ...      ...
# 999995    16873858  241b25e794bb96      1318775  1123148136        3
# 999996    16873865  82cb25078d7865      1653851  1123148476        2
# 999997    16874363  1a9b29a1803752       160751  1123183893        3
# 999998    16874364  b983ed36310309      2825696  1123183926        2
# 999999    16874525  d779ae4cfe3100      2681997  1123195210        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Merging events 'ev' & documents_meta 'dm' & click_trains_sample 'cts' dataframe with promoted_content 'pc'
evdmctspc = pd.merge(evdmcts, pc, on='ad_id')
evdmctspc
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %% [markdown]
# Copying the original dataframe before adding columns

# %%
# Copying the orginal dataframe 'evdmctspc' for safety as 'ogdf', a shorter dataframe name
ogdf = evdmctspc.copy()
ogdf
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Copying the orginal dataframe 'evdmctspc' and assinging the dataframe as 'df'. This is the dataframe 'df' we going to add columns and etc onto.
df = evdmctspc.copy()
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %% [markdown]
# Adding columns to the dataframe

# %%
# timestamp to be converted like the publish_time column from timestamp column
df['converted_timestamp'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')) 
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_year' column to get the year of the datetime from the 'timestamp' column
df['timestamp_year'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.year
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_month' column to get the month of the datetime from the 'timestamp' column
df['timestamp_month'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.month
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_day' column to get the days of the datetime from the 'timestamp' column
df['timestamp_day'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.day
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_hour' column to get hour of day from 'timestamp' column
df['timestamp_hour'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.hour
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_minute' column to get the minute of the datetime from the 'timestamp' column
df['timestamp_minute'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.minute
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_dayofweek' column to get the day of week from the 'timestamp' column
df['timestamp_dayofweek'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.dayofweek
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_dayofweekname' column to get the days of the datetime from the 'timestamp' column
df['timestamp_dayofweek_name'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.day_name()
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# Adding 'timestamp_month_name' column to get the month name of the datetime from the 'timestamp' column
df['timestamp_month_name'] = (df['timestamp'] + 1465876799998).apply(lambda t: pd.Timestamp(t, unit= 'ms')).dt.month_name()
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
# converting 'publish time' column to datetime 
# To coerce 'publish_time1' to either a valid Pandas Timestamp or pd.NaT ("not a time")
# This will give NaT as the difference in those spots
df['the_publish_time'] = pd.to_datetime(df['publish_time'], errors='coerce')
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_year'] = df.the_publish_time.dt.year
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_month'] = df.the_publish_time.dt.month
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_day'] = df.the_publish_time.dt.day
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_hour'] = df.the_publish_time.dt.hour
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_minute'] = df.the_publish_time.dt.minute
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_dayofweek'] = df.the_publish_time.dt.dayofweek
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_dayofweek_name'] = df.the_publish_time.dt.day_name()
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df['publish_time_month_name'] = df.the_publish_time.dt.month_name()
df
# Out:
#         display_id            uuid  document_id_x   timestamp platform  \
# 0            34922  6288e67b1d54c6        1794259     2600122        2
# 1          3982567  f90db73a75332d        1060089   253476258        1
# 2          7604922  9853a49f80e2f8        1303771   520980585        2
# 3          1439583  e4d4a17cf8c7e6        1667632    86010864        2
# 4          3522033  4789ccff327551        1601704   228163963        2
# ...            ...             ...            ...         ...      ...
# 999995    16841692  d2e3542e47da0e         624053  1121126231        1
# 999996    16866762  68ec61d8fa368f        2824990  1122675040        3
# 999997    16859782  cf08c047cfc412        1073469  1122222637        2
# 999998    16870073  a06a4e9ca33248         385256  1122891563        1
# 999999    16873865  82cb25078d7865        1653851  1123148476        2
#
#        geo_location  source_id  publisher_id         publish_time   ad_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   display_id                   1000000 non-null  int64
#  1   uuid                         1000000 non-null  object
#  2   document_id_x                1000000 non-null  int64
#  3   timestamp                    1000000 non-null  int64
#  4   platform                     1000000 non-null  object
#  5   geo_location                 999982 non-null   object
#  6   source_id                    999982 non-null   float64
#  7   publisher_id                 999982 non-null   float64
#  8   publish_time                 860325 non-null   object
#  9   ad_id                        1000000 non-null  int64
#  10  clicked                      1000000 non-null  int64
#  11  document_id_y                1000000 non-null  int64
# ...

# %% [markdown]
# Fixing the platform issue

# %%
df.platform.value_counts()
# Out:
# 1    412028
# 2    407634
# 3    141499
# 1     18299
# 2     15258
# 3      5282
# Name: platform, dtype: int64

# %%
Exporting the dataframe to solve the issue above

# %%
df.to_csv("newdf.csv")
